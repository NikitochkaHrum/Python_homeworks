# %%
import pandas as pd

# %%
data = pd.read_csv("done.csv")

# %%
check = pd.Series(data["Аниме"])
check.loc[check.values==True]=1
check.loc[check.values==False]=0
check.astype('int8')
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 193    0
# 194    1
# 195    1
# 196    0
# 197    0
# Name: Аниме, Length: 198, dtype: int8

# %%
data.drop(["Unnamed: 0", "time", "Драма", "Боевик", "Аниме", "Комедия", "Фантастика", "Исторический фильм", "Детектив", "Трагедия", "Фильм ужасов"], axis=1, inplace=True)

# %%
data.head()
# Out:
#    sex  vegan  rest  games  series  books  english  USSR_lover  \
# 0    1      2     1      1       1      3        1           0
# 1    0      2     1      3       1      2        3           0
# 2    1      2     0      0       1      3        3           0
# 3    0      0     0      2       3      4        3           1
# 4    0      1     1      6       4      3        1           1
#
#    child_offence_Не били  child_offence_Разве что по делу  ...  \
# 0                      1                                0  ...
# 1                      0                                1  ...
# 2                      0                                1  ...
# 3                      0                                1  ...
# 4                      1                                0  ...
#
#    subject_История  subject_Литература  subject_Матеша  subject_Физика  \
# 0                0                   1               0               0
# ...

# %%
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, Pool

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(data, check, train_size=0.5, random_state=1234)

# %%
X_validation.head()
# Out:
#      sex  vegan  rest  games  series  books  english  USSR_lover  \
# 195    0      2     0      1       4      4        0           1
# 155    1      1     1      0       4      5        1           1
# 31     1      4     1      0       3      6        1           1
# 48     1      2     1      0       5      3        4           0
# 63     1      2     1      0       2      2        3           0
#
#      child_offence_Не били  child_offence_Разве что по делу  ...  \
# 195                      0                                0  ...
# 155                      0                                1  ...
# 31                       1                                0  ...
# 48                       0                                1  ...
# 63                       1                                0  ...
#
#      subject_История  subject_Литература  subject_Матеша  subject_Физика  \
# 195                0                   0               1               0
# ...

# %%
X_train.head()
# Out:
#      sex  vegan  rest  games  series  books  english  USSR_lover  \
# 12     1      0     0      0       0      2        1           0
# 188    0      1     1      3       2      4        1           1
# 167    1      3     1      1       4      3        0           1
# 161    0      0     0      1       4      3        2           0
# 1      0      2     1      3       1      2        3           0
#
#      child_offence_Не били  child_offence_Разве что по делу  ...  \
# 12                       1                                0  ...
# 188                      0                                1  ...
# 167                      1                                0  ...
# 161                      1                                0  ...
# 1                        0                                1  ...
#
#      subject_История  subject_Литература  subject_Матеша  subject_Физика  \
# 12                 0                   0               1               0
# ...

# %%
import numpy as np

# %%
best_model = CatBoostClassifier(iterations=10)

# %%
train_data= Pool(data=X_train, label=Y_train, weight=np.ones(Y_train.size))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-fcff18fdfaa2> in <module>
# ----> 1 train_data= Pool(data=X_train, label=Y_train, weight=np.ones(Y_train.size))
#
# ~/anaconda3/lib/python3.8/site-packages/catboost/core.py in __init__(self, data, label, cat_features, text_features, embedding_features, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     586                     )
#     587
# --> 588                 self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     589         super(Pool, self).__init__()
#     590
#
# ...
