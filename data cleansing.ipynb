# %%
import pandas as pd

# %%
data = pd.read_csv('form.csv', parse_dates = ['Отметка времени'])

# %%
data.head()
# Out:
#       Отметка времени Мальчик или девочка? Как часто тебя били в детстве?  \
# 0 2019-09-06 23:22:11              Девочка                        Не били
# 1 2019-09-06 23:27:43              Мальчик              Разве что по делу
# 2 2019-09-06 23:30:07              Девочка              Разве что по делу
# 3 2019-09-06 23:30:08              Мальчик              Разве что по делу
# 4 2019-09-06 23:31:38              Мальчик                        Не били
#
#    Оцените ваш уровень вегетарианца по 5-ти бальной шкале  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                  1
#
#       Что такое два.ч? Твоя ориентация?  \
# 0              Не знаю           Гетеро
# 1         Ненавижу Абу           Гетеро
# 2          Паблик в вк           Гетеро
# 3  Лучшая борда рунета           Гетеро
# 4         Ненавижу Абу           Гетеро
#
#   Погулять вечером после тяжкого рабочего дня, или посычевать дома?  \
# 0                                           Сычевать
# 1                                           Сычевать
# 2                                             Гулять
# 3                                             Гулять
# 4                                           Сычевать
#
#    Как часто играешь в игры?  Сериалы?  А книги?  Вы таки антисемит?   \
# 0                          1         1          3                 Нет
# 1                          3         1          2                 Нет
# 2                          0         1          3                 Нет
# 3                          2         3          4                 Нет
# 4                          6         4          3                 Нет
#
#   Какой предмет ближе всего по душе? Как вы относитесь к аннексии Крыма?  \
# 0                         Литература                        Положительно
# 1                             Матеша                       Мне всё равно
# 2                        Информатика                       Мне всё равно
# 3                        Информатика                        Отрицательно
# 4                        Информатика                       Мне всё равно
#
#        Владимир Путин -  Как хорошо вы знаете английский?  \
# 0                   Краб           Чуть лучше, чем ничего
# 1                человек                           Хорошо
# 2  Политик, лидер и боец                           Хорошо
# 3  Политик, лидер и боец                           Хорошо
# 4  Политик, лидер и боец           Чуть лучше, чем ничего
#
#         Было ли раньше лучше?   \
# 0                          Нет
# 1                          Нет
# 2                          Нет
# 3  А колбаса какая, колбаса...
# 4  А колбаса какая, колбаса...
#
#                       А какие жанры фильмов любишь?
# 0  Детектив, Аниме, Драма, Комедия, Исторический ...
# 1       Детектив, Трагедия, Фильм ужасов, Фантастика
# 2   Боевик, Детектив, Комедия, Мелодрама, Фантастика
# 3  Боевик, Детектив, Аниме, Комедия, Мелодрама, И...
# 4  Боевик, Детектив, Аниме, Драма, Комедия, Истор...

# %%
data.rename(columns={'Отметка времени':'time', 'Мальчик или девочка?':'sex', 'Как часто тебя били в детстве?':'child_offence'}, inplace=True)

# %%
data.rename(columns={'Оцените ваш уровень вегетарианца по 5-ти бальной шкале':'vegan', 'Что такое два.ч?':'dvach', 'Твоя ориентация?':'gender'}, inplace=True)

# %%
data.rename(columns={'Погулять вечером после тяжкого рабочего дня, или посычевать дома?':'rest', 'Как часто играешь в игры?':'games'}, inplace=True)

# %%
data.rename(columns={'Сериалы?':'series', 'А книги? ':'books', 'Вы таки антисемит? ':'antisemetism'}, inplace=True)

# %%
data.rename(columns={'Какой предмет ближе всего по душе?':'subject', 'Как вы относитесь к аннексии Крыма?':'crimea', 'Владимир Путин - ':'putin'}, inplace=True)

# %%
data.rename(columns={'Как хорошо вы знаете английский?':'english', 'Было ли раньше лучше? ':'USSR_lover', 'А какие жанры фильмов любишь? ':'films'}, inplace=True)

# %%
data.tail()
# Out:
#                    time      sex      child_offence  vegan  \
# 193 2020-10-31 18:06:00  Мальчик  Разве что по делу      3
# 194 2020-10-31 18:56:01  Мальчик              Часто      2
# 195 2020-10-31 19:10:22  Мальчик              Часто      2
# 196 2020-10-31 20:20:18  Мальчик            Не били      3
# 197 2020-10-31 21:42:02  Девочка              Часто      2
#
#                    dvach  gender      rest  games  series  books  \
# 193         Ненавижу Абу      Би  Сычевать      6       0      2
# 194  Лучшая борда рунета  Гетеро    Гулять      4       4      2
# 195         Ненавижу Абу      Би    Гулять      1       4      4
# 196              Не знаю  Гетеро  Сычевать      4       2      0
# 197              Не знаю  Гетеро  Сычевать      1       4      5
#
#               antisemetism      subject         crimea                  putin  \
# 193                    Нет       Матеша   Отрицательно                Молодец
# 194                    Нет  Информатика  Мне всё равно  Политик, лидер и боец
# 195  Я просто боюсь евреев       Матеша  Мне всё равно            мое дружище
# 196                    Нет  Информатика  Мне всё равно                    ...
# 197                    Нет   Литература  Мне всё равно  Политик, лидер и боец
#
#                   english                   USSR_lover  \
# 193  НЭЙТИВ ИНГЛИШ СПИКЕР                          Нет
# 194             Нормально                          Нет
# 195    Оригатоё гайзаймас  А колбаса какая, колбаса...
# 196             Нормально                          Нет
# 197             Нормально                          Нет
#
#                                                  films
# 193  Драма, Комедия, Трагедия, Фильм ужасов, Фантас...
# 194  Боевик, Детектив, Аниме, Драма, Комедия, Траге...
# 195                                              Аниме
# 196                        Боевик, Комедия, Фантастика
# 197       Боевик, Детектив, Драма, Комедия, Фантастика

# %%
data.dtypes
# Out:
# time             datetime64[ns]
# sex                      object
# child_offence            object
# vegan                     int64
# dvach                    object
# gender                   object
# rest                     object
# games                     int64
# series                    int64
# books                     int64
# antisemetism             object
# subject                  object
# crimea                   object
# putin                    object
# english                  object
# USSR_lover               object
# films                    object
# dtype: object

# %%
data.loc[data.sex=='Мальчик', ['sex']]=0
data.loc[data.sex=='Девочка', ['sex']]=1

# %%
data.sex=data.sex.astype('int8')

# %%
data.tail()
# Out:
#                    time  sex      child_offence  vegan                dvach  \
# 193 2020-10-31 18:06:00    0  Разве что по делу      3         Ненавижу Абу
# 194 2020-10-31 18:56:01    0              Часто      2  Лучшая борда рунета
# 195 2020-10-31 19:10:22    0              Часто      2         Ненавижу Абу
# 196 2020-10-31 20:20:18    0            Не били      3              Не знаю
# 197 2020-10-31 21:42:02    1              Часто      2              Не знаю
#
#      gender      rest  games  series  books           antisemetism  \
# 193      Би  Сычевать      6       0      2                    Нет
# 194  Гетеро    Гулять      4       4      2                    Нет
# 195      Би    Гулять      1       4      4  Я просто боюсь евреев
# 196  Гетеро  Сычевать      4       2      0                    Нет
# 197  Гетеро  Сычевать      1       4      5                    Нет
#
#          subject         crimea                  putin               english  \
# 193       Матеша   Отрицательно                Молодец  НЭЙТИВ ИНГЛИШ СПИКЕР
# 194  Информатика  Мне всё равно  Политик, лидер и боец             Нормально
# 195       Матеша  Мне всё равно            мое дружище    Оригатоё гайзаймас
# 196  Информатика  Мне всё равно                    ...             Нормально
# 197   Литература  Мне всё равно  Политик, лидер и боец             Нормально
#
#                       USSR_lover  \
# 193                          Нет
# 194                          Нет
# 195  А колбаса какая, колбаса...
# 196                          Нет
# 197                          Нет
#
#                                                  films
# 193  Драма, Комедия, Трагедия, Фильм ужасов, Фантас...
# 194  Боевик, Детектив, Аниме, Драма, Комедия, Траге...
# 195                                              Аниме
# 196                        Боевик, Комедия, Фантастика
# 197       Боевик, Детектив, Драма, Комедия, Фантастика

# %%
data.sex.dtype
# Out:
# dtype('int8')

# %%
data.loc[data.rest=='Гулять', ['rest']]=0
data.loc[data.rest=='Сычевать', ['rest']]=1

# %%
data.rest=data.rest.astype('int8')

# %%
data.tail()
# Out:
#                    time  sex      child_offence  vegan                dvach  \
# 193 2020-10-31 18:06:00    0  Разве что по делу      3         Ненавижу Абу
# 194 2020-10-31 18:56:01    0              Часто      2  Лучшая борда рунета
# 195 2020-10-31 19:10:22    0              Часто      2         Ненавижу Абу
# 196 2020-10-31 20:20:18    0            Не били      3              Не знаю
# 197 2020-10-31 21:42:02    1              Часто      2              Не знаю
#
#      gender  rest  games  series  books           antisemetism      subject  \
# 193      Би     1      6       0      2                    Нет       Матеша
# 194  Гетеро     0      4       4      2                    Нет  Информатика
# 195      Би     0      1       4      4  Я просто боюсь евреев       Матеша
# 196  Гетеро     1      4       2      0                    Нет  Информатика
# 197  Гетеро     1      1       4      5                    Нет   Литература
#
#             crimea                  putin               english  \
# 193   Отрицательно                Молодец  НЭЙТИВ ИНГЛИШ СПИКЕР
# 194  Мне всё равно  Политик, лидер и боец             Нормально
# 195  Мне всё равно            мое дружище    Оригатоё гайзаймас
# 196  Мне всё равно                    ...             Нормально
# 197  Мне всё равно  Политик, лидер и боец             Нормально
#
#                       USSR_lover  \
# 193                          Нет
# 194                          Нет
# 195  А колбаса какая, колбаса...
# 196                          Нет
# 197                          Нет
#
#                                                  films
# 193  Драма, Комедия, Трагедия, Фильм ужасов, Фантас...
# 194  Боевик, Детектив, Аниме, Драма, Комедия, Траге...
# 195                                              Аниме
# 196                        Боевик, Комедия, Фантастика
# 197       Боевик, Детектив, Драма, Комедия, Фантастика

# %%
data.rest.dtype
# Out:
# dtype('int8')

# %%
data.loc[data.english == 'Оригатоё гайзаймас', ['english']]=0
data.loc[data.english == 'Чуть лучше, чем ничего', ['english']]=1
data.loc[data.english == 'Нормально', ['english']]=2
data.loc[data.english == 'Хорошо', ['english']]=3
data.loc[data.english == 'Отлично', ['english']]=4
data.loc[data.english == 'НЭЙТИВ ИНГЛИШ СПИКЕР', ['english']]=5
data.english=data.english.astype('int8')

# %%
data.tail()
# Out:
#                    time  sex      child_offence  vegan                dvach  \
# 193 2020-10-31 18:06:00    0  Разве что по делу      3         Ненавижу Абу
# 194 2020-10-31 18:56:01    0              Часто      2  Лучшая борда рунета
# 195 2020-10-31 19:10:22    0              Часто      2         Ненавижу Абу
# 196 2020-10-31 20:20:18    0            Не били      3              Не знаю
# 197 2020-10-31 21:42:02    1              Часто      2              Не знаю
#
#      gender  rest  games  series  books           antisemetism      subject  \
# 193      Би     1      6       0      2                    Нет       Матеша
# 194  Гетеро     0      4       4      2                    Нет  Информатика
# 195      Би     0      1       4      4  Я просто боюсь евреев       Матеша
# 196  Гетеро     1      4       2      0                    Нет  Информатика
# 197  Гетеро     1      1       4      5                    Нет   Литература
#
#             crimea                  putin  english  \
# 193   Отрицательно                Молодец        5
# 194  Мне всё равно  Политик, лидер и боец        2
# 195  Мне всё равно            мое дружище        0
# 196  Мне всё равно                    ...        2
# 197  Мне всё равно  Политик, лидер и боец        2
#
#                       USSR_lover  \
# 193                          Нет
# 194                          Нет
# 195  А колбаса какая, колбаса...
# 196                          Нет
# 197                          Нет
#
#                                                  films
# 193  Драма, Комедия, Трагедия, Фильм ужасов, Фантас...
# 194  Боевик, Детектив, Аниме, Драма, Комедия, Траге...
# 195                                              Аниме
# 196                        Боевик, Комедия, Фантастика
# 197       Боевик, Детектив, Драма, Комедия, Фантастика

# %%
data.dtypes
# Out:
# time             datetime64[ns]
# sex                        int8
# child_offence            object
# vegan                     int64
# dvach                    object
# gender                   object
# rest                       int8
# games                     int64
# series                    int64
# books                     int64
# antisemetism             object
# subject                  object
# crimea                   object
# putin                    object
# english                    int8
# USSR_lover               object
# films                    object
# dtype: object

# %%
data = data.join(pd.get_dummies(data.child_offence, prefix = 'child_offence'))

# %%
data = data.join(pd.get_dummies(data.dvach, prefix = 'dvach'))

# %%
data = data.join(pd.get_dummies(data.gender, prefix = 'gender'))

# %%
data = data.join(pd.get_dummies(data.antisemetism, prefix = 'antisemetism'))

# %%
data = data.join(pd.get_dummies(data.subject, prefix = 'subject'))

# %%
data = data.join(pd.get_dummies(data.crimea, prefix = 'crimea'))

# %%
data.tail()
# Out:
#                    time  sex      child_offence  vegan                dvach  \
# 193 2020-10-31 18:06:00    0  Разве что по делу      3         Ненавижу Абу
# 194 2020-10-31 18:56:01    0              Часто      2  Лучшая борда рунета
# 195 2020-10-31 19:10:22    0              Часто      2         Ненавижу Абу
# 196 2020-10-31 20:20:18    0            Не били      3              Не знаю
# 197 2020-10-31 21:42:02    1              Часто      2              Не знаю
#
#      gender  rest  games  series  books  ... subject_Иностранные языки  \
# 193      Би     1      6       0      2  ...                         0
# 194  Гетеро     0      4       4      2  ...                         0
# 195      Би     0      1       4      4  ...                         0
# 196  Гетеро     1      4       2      0  ...                         0
# 197  Гетеро     1      1       4      5  ...                         0
#
#     subject_Информатика subject_История subject_Литература  subject_Матеша  \
# 193                   0               0                  0               1
# 194                   1               0                  0               0
# 195                   0               0                  0               1
# 196                   1               0                  0               0
# 197                   0               0                  1               0
#
#     subject_Физика subject_Химия  crimea_Мне всё равно  crimea_Отрицательно  \
# 193              0             0                     0                    1
# 194              0             0                     1                    0
# 195              0             0                     1                    0
# 196              0             0                     1                    0
# 197              0             0                     1                    0
#
#      crimea_Положительно
# 193                    0
# 194                    0
# 195                    0
# 196                    0
# 197                    0
#
# [5 rows x 41 columns]

# %%
data.drop(['child_offence', 'dvach', 'gender', 'antisemetism', 'subject', 'crimea'], axis=1, inplace=True)

# %%
data.tail()
# Out:
#                    time  sex  vegan  rest  games  series  books  \
# 193 2020-10-31 18:06:00    0      3     1      6       0      2
# 194 2020-10-31 18:56:01    0      2     0      4       4      2
# 195 2020-10-31 19:10:22    0      2     0      1       4      4
# 196 2020-10-31 20:20:18    0      3     1      4       2      0
# 197 2020-10-31 21:42:02    1      2     1      1       4      5
#
#                      putin  english                   USSR_lover  ...  \
# 193                Молодец        5                          Нет  ...
# 194  Политик, лидер и боец        2                          Нет  ...
# 195            мое дружище        0  А колбаса какая, колбаса...  ...
# 196                    ...        2                          Нет  ...
# 197  Политик, лидер и боец        2                          Нет  ...
#
#     subject_Иностранные языки  subject_Информатика  subject_История  \
# 193                         0                    0                0
# 194                         0                    1                0
# 195                         0                    0                0
# 196                         0                    1                0
# 197                         0                    0                0
#
#      subject_Литература  subject_Матеша  subject_Физика  subject_Химия  \
# 193                   0               1               0              0
# 194                   0               0               0              0
# 195                   0               1               0              0
# 196                   0               0               0              0
# 197                   1               0               0              0
#
#      crimea_Мне всё равно  crimea_Отрицательно  crimea_Положительно
# 193                     0                    1                    0
# 194                     1                    0                    0
# 195                     1                    0                    0
# 196                     1                    0                    0
# 197                     1                    0                    0
#
# [5 rows x 35 columns]

# %%
data.loc[data.putin == 'Молодец', ['putin']]='putin_good'
data.loc[data.putin == 'Политик, лидер и боец', ['putin']]='putin_good'

# %%
data.loc[data.putin != 'putin_good', ['putin']]='rebel'

# %%
data = data.join(pd.get_dummies(data.putin))

# %%
data.drop(['putin'], axis=1, inplace=True)

# %%
data.tail()
# Out:
#                    time  sex  vegan  rest  games  series  books  english  \
# 193 2020-10-31 18:06:00    0      3     1      6       0      2        5
# 194 2020-10-31 18:56:01    0      2     0      4       4      2        2
# 195 2020-10-31 19:10:22    0      2     0      1       4      4        0
# 196 2020-10-31 20:20:18    0      3     1      4       2      0        2
# 197 2020-10-31 21:42:02    1      2     1      1       4      5        2
#
#                       USSR_lover  \
# 193                          Нет
# 194                          Нет
# 195  А колбаса какая, колбаса...
# 196                          Нет
# 197                          Нет
#
#                                                  films  ...  subject_История  \
# 193  Драма, Комедия, Трагедия, Фильм ужасов, Фантас...  ...                0
# 194  Боевик, Детектив, Аниме, Драма, Комедия, Траге...  ...                0
# 195                                              Аниме  ...                0
# 196                        Боевик, Комедия, Фантастика  ...                0
# 197       Боевик, Детектив, Драма, Комедия, Фантастика  ...                0
#
#      subject_Литература  subject_Матеша  subject_Физика  subject_Химия  \
# 193                   0               1               0              0
# 194                   0               0               0              0
# 195                   0               1               0              0
# 196                   0               0               0              0
# 197                   1               0               0              0
#
#      crimea_Мне всё равно  crimea_Отрицательно  crimea_Положительно  \
# 193                     0                    1                    0
# 194                     1                    0                    0
# 195                     1                    0                    0
# 196                     1                    0                    0
# 197                     1                    0                    0
#
#      putin_good  rebel
# 193           1      0
# 194           1      0
# 195           0      1
# 196           0      1
# 197           1      0
#
# [5 rows x 36 columns]

# %%
data.loc[data.USSR_lover != 'Нет', ['USSR_lover']]=1
data.loc[data.USSR_lover == 'Нет', ['USSR_lover']]=0

# %%
data.tail()
# Out:
#                    time  sex  vegan  rest  games  series  books  english  \
# 193 2020-10-31 18:06:00    0      3     1      6       0      2        5
# 194 2020-10-31 18:56:01    0      2     0      4       4      2        2
# 195 2020-10-31 19:10:22    0      2     0      1       4      4        0
# 196 2020-10-31 20:20:18    0      3     1      4       2      0        2
# 197 2020-10-31 21:42:02    1      2     1      1       4      5        2
#
#     USSR_lover                                              films  ...  \
# 193          0  Драма, Комедия, Трагедия, Фильм ужасов, Фантас...  ...
# 194          0  Боевик, Детектив, Аниме, Драма, Комедия, Траге...  ...
# 195          1                                              Аниме  ...
# 196          0                        Боевик, Комедия, Фантастика  ...
# 197          0       Боевик, Детектив, Драма, Комедия, Фантастика  ...
#
#      subject_История  subject_Литература  subject_Матеша  subject_Физика  \
# 193                0                   0               1               0
# 194                0                   0               0               0
# 195                0                   0               1               0
# 196                0                   0               0               0
# 197                0                   1               0               0
#
#      subject_Химия  crimea_Мне всё равно  crimea_Отрицательно  \
# 193              0                     0                    1
# 194              0                     1                    0
# 195              0                     1                    0
# 196              0                     1                    0
# 197              0                     1                    0
#
#      crimea_Положительно  putin_good  rebel
# 193                    0           1      0
# 194                    0           1      0
# 195                    0           0      1
# 196                    0           0      1
# 197                    0           1      0
#
# [5 rows x 36 columns]

# %%
lol= pd.Series(data['films'].str.split(','))

# %%
lol
# Out:
# 0      [Детектив,  Аниме,  Драма,  Комедия,  Историче...
# 1      [Детектив,  Трагедия,  Фильм ужасов,  Фантастика]
# 2      [Боевик,  Детектив,  Комедия,  Мелодрама,  Фан...
# 3      [Боевик,  Детектив,  Аниме,  Комедия,  Мелодра...
# 4      [Боевик,  Детектив,  Аниме,  Драма,  Комедия, ...
#                              ...
# 193    [Драма,  Комедия,  Трагедия,  Фильм ужасов,  Ф...
# 194    [Боевик,  Детектив,  Аниме,  Драма,  Комедия, ...
# 195                                              [Аниме]
# 196                      [Боевик,  Комедия,  Фантастика]
# 197    [Боевик,  Детектив,  Драма,  Комедия,  Фантаст...
# Name: films, Length: 198, dtype: object

# %%
#data.films=lol

# %%
genres=set()

# %%
for tec in lol:
    for genre in tec:
        if genre[0]!=' ':
            genres.add(genre)

# %%
genres
# Out:
# {'Аниме',
#  'Боевик',
#  'Детектив',
#  'Драма',
#  'Исторический фильм',
#  'Комедия',
#  'Трагедия',
#  'Фантастика',
#  'Фильм ужасов'}

# %%
for genre in genres:
    data[genre]=False

# %%
data.tail()
# Out:
#                    time  sex  vegan  rest  games  series  books  english  \
# 193 2020-10-31 18:06:00    0      3     1      6       0      2        5
# 194 2020-10-31 18:56:01    0      2     0      4       4      2        2
# 195 2020-10-31 19:10:22    0      2     0      1       4      4        0
# 196 2020-10-31 20:20:18    0      3     1      4       2      0        2
# 197 2020-10-31 21:42:02    1      2     1      1       4      5        2
#
#     USSR_lover                                              films  ...  rebel  \
# 193          0  Драма, Комедия, Трагедия, Фильм ужасов, Фантас...  ...      0
# 194          0  Боевик, Детектив, Аниме, Драма, Комедия, Траге...  ...      0
# 195          1                                              Аниме  ...      1
# 196          0                        Боевик, Комедия, Фантастика  ...      1
# 197          0       Боевик, Детектив, Драма, Комедия, Фантастика  ...      0
#
#      Драма  Боевик  Аниме  Комедия  Фантастика  Исторический фильм  Детектив  \
# 193  False   False  False    False       False               False     False
# 194  False   False  False    False       False               False     False
# 195  False   False  False    False       False               False     False
# 196  False   False  False    False       False               False     False
# 197  False   False  False    False       False               False     False
#
#      Трагедия  Фильм ужасов
# 193     False         False
# 194     False         False
# 195     False         False
# 196     False         False
# 197     False         False
#
# [5 rows x 45 columns]

# %%
for genre in genres:
    data.loc[data.films.str.contains(genre), [genre]]=True

# %%
data.drop(['films'], axis=1, inplace=True)

# %%
data.tail()
# Out:
#                    time  sex  vegan  rest  games  series  books  english  \
# 193 2020-10-31 18:06:00    0      3     1      6       0      2        5
# 194 2020-10-31 18:56:01    0      2     0      4       4      2        2
# 195 2020-10-31 19:10:22    0      2     0      1       4      4        0
# 196 2020-10-31 20:20:18    0      3     1      4       2      0        2
# 197 2020-10-31 21:42:02    1      2     1      1       4      5        2
#
#     USSR_lover  child_offence_Не били  ...  rebel  Драма  Боевик  Аниме  \
# 193          0                      0  ...      0   True   False  False
# 194          0                      0  ...      0   True    True   True
# 195          1                      0  ...      1  False   False   True
# 196          0                      1  ...      1  False    True  False
# 197          0                      0  ...      0   True    True  False
#
#      Комедия  Фантастика  Исторический фильм  Детектив  Трагедия  Фильм ужасов
# 193     True        True               False     False      True          True
# 194     True        True               False      True      True          True
# 195    False       False               False     False     False         False
# 196     True        True               False     False     False         False
# 197     True        True               False      True     False         False
#
# [5 rows x 44 columns]

# %%
data.to_csv('done.csv')
